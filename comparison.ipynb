# %%
from data_filters.config import get_config_from_file
from data_filters.main import build_filter_runner_from_config, build_smoother_from_config, univariate_process
from data_filters.utilities import mirror
from data_filters.plots import UnivariatePlotter
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
def get_df_from_raw_data(
    df: pd.DataFrame, first_date=None, last_date=None
) -> pd.DataFrame:
    df["Calculated_timestamp"] = pd.to_datetime(df["Calculated_timestamp"])
    data = df.set_index("Calculated_timestamp")
    if first_date:
        first_date = pd.to_datetime(first_date, format="%Y-%m-%d")
        data = data.loc[data.index > first_date]
    if last_date:
        last_date = pd.to_datetime(last_date, format="%Y-%m-%d")
        data = data.loc[data.index < last_date]
    value_columns = [col for col in data.columns if ("value" in col)]
    quality_columns = [col for col in data.columns if ("qualityFlag" in col)]
    data = data.dropna(subset=value_columns, how="all", axis=0)
    data[quality_columns] = data[quality_columns].astype(bool)
    return data.loc[:, value_columns + quality_columns]

# %%
def prepare_time_series(
    ts: pd.Series,
    data: pd.DataFrame,
    flow_name: str,
    use_log=False,
    use_flow=False,
    is_flag=False,
) -> pd.Series:
    series_name = "SRAS"
    if use_flow:
        ts = ts * data[flow_name] / 1e3  # Tgc/d
        series_name += " x Débit"
    ts = ts.dropna()

    if use_log:
        ts = np.log(ts + 0.001)
        series_name = f"log({series_name})"

    series_name = "Manually flagged" if is_flag else series_name
    ts.name = series_name
    return ts.asfreq("D")

# %%
def retrieve_flagged_data(
    data: pd.DataFrame, series_name: str, quality_name: str
) -> pd.Series:
    ts = data[series_name]  # gc/ml
    flags = data[quality_name].fillna(False)
    flagged = ts.loc[flags]
    flagged.name = "Flagged"
    return flagged

# %%
def remove_flagged(time_series: pd.Series, flags: pd.Series) -> pd.Series:
    df = pd.concat([time_series, flags], axis=1)
    flag_name = flags.name
    df["keep"] = df.apply(lambda x: np.isnan(x[flag_name]), axis=1)
    return time_series.loc[df["keep"]]

# %%
def write_units(use_log: bool, use_flow: bool) -> str:
    units = "1e9 cg/j" if use_flow else "cg/j"
    if use_log:
        units = f"log ({units})"
    return units

# %%
CONFIG_PATH = "+flow-log.yaml"
config = get_config_from_file(CONFIG_PATH)
DATA_PATH = "/Users/jeandavidt/Library/CloudStorage/OneDrive-UniversitéLaval/Université/Doctorat/COVID/Latest Data/wide tables 2022/qc_01.csv"

SARS_NAME = "WWMeasure_covn1_gcml_single-to-mean_value"
SARS_QUALITY_NAME = "WWMeasure_covn1_gcml_single-to-mean_qualityFlag"
FLOW_NAME = "SiteMeasure_wwflow_m3d_single-to-mean_value"

YEAR = 2022

start = config.filtration_period.start
end = config.filtration_period.end

use_mirror = True
use_log = "+" in CONFIG_PATH.split("flow")[1]
use_flow = "+" in CONFIG_PATH.split("flow")[0]
remove_flags = False

raw_data = pd.read_csv(DATA_PATH)
data = get_df_from_raw_data(raw_data, first_date=start, last_date=end)

if YEAR == 2021:
    SARS_NAME = SARS_NAME.replace("n1", "n2")
    SARS_QUALITY_NAME = SARS_QUALITY_NAME.replace("n1", "n2")

flagged = retrieve_flagged_data(data, SARS_NAME, SARS_QUALITY_NAME)
original_time_series = data[SARS_NAME]
flagged = prepare_time_series(
    flagged, data, FLOW_NAME, use_log, use_flow, is_flag=True
)
original_time_series = prepare_time_series(
    original_time_series, data, FLOW_NAME, use_log, use_flow, is_flag=False
)
if remove_flags:
    time_series = remove_flagged(original_time_series, flagged)
else:
    time_series = original_time_series.copy()
time_series = time_series.asfreq("D").interpolate()
units = write_units(use_log, use_flow)

if use_mirror:
    # lengthen the series by mirroring
    mirrored_df = mirror(time_series, first_date=start, last_date=end)
    mirrored_df = mirror(mirrored_df)

    # fill gaps
    time_series = mirrored_df.interpolate()

# seven-day rolling average
seven_days = time_series.rolling(window=7, center=True).mean()

filter_runner = build_filter_runner_from_config(config)
smoother = build_smoother_from_config(config)

filter_results = univariate_process(
    raw_data=time_series,
    calibration_period=config.calibration_period,
    filter_runner=filter_runner,
    smoother=smoother
)

# plotter
plotter = UnivariatePlotter(
    signal_name="SARS", df=filter_results, template="plotly_white", language="french"
)
fig = plotter.plot()

raw_trace = go.Scatter(
    x=original_time_series.index,
    y=original_time_series,
    name="Signal brut",
    marker=dict(color="#bbbbbb"),
)
fig.add_trace(raw_trace)

# flagged_trace = go.Scatter(x=flagged.index, y=flagged, name="Annoté manuellement", line=dict(color="#D62728"), mode='markers', marker=dict(symbol="star", size=15), showlegend=True)
# fig.add_trace(flagged_trace)

seven_day_trace = go.Scatter(
    x=seven_days.index,
    y=seven_days,
    name="Liss. moy. 7j",
    marker=dict(color="#FF6F00"),
)
fig.add_trace(seven_day_trace)

start = time_series.first_valid_index() if start is None else start
end = (time_series.last_valid_index() if end is None else end) + pd.to_timedelta(1, "D")
fig.update_layout(
    dict(
        # template="presentation",
        title=f"Surveillance des eaux usées - Ville de Québec, Station Est - {time_series.name}"
    ),
    yaxis=dict(title=f"Valeur ({units})"),
    xaxis=dict(title="Jour d'échantillonnage", range=[start, end]),
),
fig.update_layout(dict(hovermode="x unified", width=1000, height=800))
fig.update_traces(hovertemplate="%{y:.2f}")
# Out:
# /Users/jeandavidt/dev/jeandavidt/data_filters/src/data_filters/utilities.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smooth_df.drop(["input_values"], axis=1, inplace=True)

# %%
fig.write_html("sars_x_flow.html")

# %%
import json
from json import JSONEncoder

# %%
smoother.__dict__
# Out:
# {'control_parameters': {'size': 2},
#  'algorithm': None,
#  'signal_model': None,
#  'uncertainty_model': None,
#  'current_position': 163,
#  'input_data':             accepted_values
#  date
#  2021-11-20        42.494004
#  2021-11-21        69.881528
#  2021-11-22        69.881528
#  2021-11-23      1668.654437
#  2021-11-24       634.699395
#  ...                     ...
#  2022-04-29       634.699395
#  2022-04-30      1668.654437
#  2022-05-01      1948.908651
#  2022-05-02      1547.234806
#  2022-05-03        42.494004
#
#  [165 rows x 1 columns],
#  'results': [FilterRow(date=NaT, input_values=array([nan]), inputs_are_outliers=array([False]), accepted_values=array([nan]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=NaT, input_values=array([nan]), inputs_are_outliers=array([False]), accepted_values=array([nan]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-22 00:00:00'), input_values=array([69.8815284]), inputs_are_outliers=array([False]), accepted_values=array([506.49692601]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-23 00:00:00'), input_values=array([1668.65443741]), inputs_are_outliers=array([False]), accepted_values=array([801.11904123]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-24 00:00:00'), input_values=array([634.69939496]), inputs_are_outliers=array([False]), accepted_values=array([938.58221428]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-25 00:00:00'), input_values=array([1408.11595309]), inputs_are_outliers=array([False]), accepted_values=array([968.32641171]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-26 00:00:00'), input_values=array([562.88459265]), inputs_are_outliers=array([False]), accepted_values=array([766.05568825]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-27 00:00:00'), input_values=array([618.2468254]), inputs_are_outliers=array([False]), accepted_values=array([639.34366716]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-28 00:00:00'), input_values=array([513.25294186]), inputs_are_outliers=array([False]), accepted_values=array([880.76693425]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-29 00:00:00'), input_values=array([200.0624127]), inputs_are_outliers=array([False]), accepted_values=array([1452.63726233]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-11-30 00:00:00'), input_values=array([3176.96115166]), inputs_are_outliers=array([False]), accepted_values=array([1674.73893649]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-01 00:00:00'), input_values=array([3210.09416331]), inputs_are_outliers=array([False]), accepted_values=array([1661.08186664]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-02 00:00:00'), input_values=array([271.19221972]), inputs_are_outliers=array([False]), accepted_values=array([1702.44864282]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-03 00:00:00'), input_values=array([384.8979567]), inputs_are_outliers=array([False]), accepted_values=array([1229.67606987]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-04 00:00:00'), input_values=array([2311.09269058]), inputs_are_outliers=array([False]), accepted_values=array([962.67051881]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-05 00:00:00'), input_values=array([463.19549486]), inputs_are_outliers=array([False]), accepted_values=array([1011.77002675]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-06 00:00:00'), input_values=array([998.36249055]), inputs_are_outliers=array([False]), accepted_values=array([873.90516067]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-07 00:00:00'), input_values=array([672.09312544]), inputs_are_outliers=array([False]), accepted_values=array([569.00074998]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-08 00:00:00'), input_values=array([122.736]), inputs_are_outliers=array([False]), accepted_values=array([476.65072566]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-09 00:00:00'), input_values=array([529.42914644]), inputs_are_outliers=array([False]), accepted_values=array([375.8446981]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-10 00:00:00'), input_values=array([177.28653417]), inputs_are_outliers=array([False]), accepted_values=array([713.16508956]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-11 00:00:00'), input_values=array([483.54973046]), inputs_are_outliers=array([False]), accepted_values=array([1290.81295341]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-12 00:00:00'), input_values=array([2788.53114788]), inputs_are_outliers=array([False]), accepted_values=array([2089.09636332]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-13 00:00:00'), input_values=array([2824.15307258]), inputs_are_outliers=array([False]), accepted_values=array([2709.35727136]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-14 00:00:00'), input_values=array([4114.28855102]), inputs_are_outliers=array([False]), accepted_values=array([3096.29474575]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-15 00:00:00'), input_values=array([2586.53827235]), inputs_are_outliers=array([False]), accepted_values=array([2854.02751805]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-16 00:00:00'), input_values=array([2863.32539379]), inputs_are_outliers=array([False]), accepted_values=array([2604.23168017]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-17 00:00:00'), input_values=array([1477.71986007]), inputs_are_outliers=array([False]), accepted_values=array([2314.95660866]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-18 00:00:00'), input_values=array([2331.81027574]), inputs_are_outliers=array([False]), accepted_values=array([2352.50937129]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-19 00:00:00'), input_values=array([2601.35116567]), inputs_are_outliers=array([False]), accepted_values=array([2457.20329964]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-20 00:00:00'), input_values=array([2786.5689419]), inputs_are_outliers=array([False]), accepted_values=array([2376.54277605]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-21 00:00:00'), input_values=array([2902.24867781]), inputs_are_outliers=array([False]), accepted_values=array([2242.52792102]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-22 00:00:00'), input_values=array([653.26456469]), inputs_are_outliers=array([False]), accepted_values=array([2196.76316098]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-23 00:00:00'), input_values=array([2316.7985564]), inputs_are_outliers=array([False]), accepted_values=array([2222.02496612]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-24 00:00:00'), input_values=array([2950.63050715]), inputs_are_outliers=array([False]), accepted_values=array([2357.51475857]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-25 00:00:00'), input_values=array([2607.96412904]), inputs_are_outliers=array([False]), accepted_values=array([2828.1451197]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-26 00:00:00'), input_values=array([2778.72244254]), inputs_are_outliers=array([False]), accepted_values=array([3194.93400878]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-27 00:00:00'), input_values=array([3596.20314952]), inputs_are_outliers=array([False]), accepted_values=array([3547.25120067]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-28 00:00:00'), input_values=array([4395.6473537]), inputs_are_outliers=array([False]), accepted_values=array([3588.80042643]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-29 00:00:00'), input_values=array([4289.62377911]), inputs_are_outliers=array([False]), accepted_values=array([3531.85230467]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-30 00:00:00'), input_values=array([2038.1498593]), inputs_are_outliers=array([False]), accepted_values=array([3140.31602125]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2021-12-31 00:00:00'), input_values=array([3134.65736523]), inputs_are_outliers=array([False]), accepted_values=array([3000.34955485]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-01 00:00:00'), input_values=array([2038.1498593]), inputs_are_outliers=array([False]), accepted_values=array([3140.31602125]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-02 00:00:00'), input_values=array([4289.62377911]), inputs_are_outliers=array([False]), accepted_values=array([3531.85230467]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-03 00:00:00'), input_values=array([4395.6473537]), inputs_are_outliers=array([False]), accepted_values=array([3588.80042643]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-04 00:00:00'), input_values=array([3596.20314952]), inputs_are_outliers=array([False]), accepted_values=array([3703.47857998]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-05 00:00:00'), input_values=array([2778.72244254]), inputs_are_outliers=array([False]), accepted_values=array([3422.2435044]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-06 00:00:00'), input_values=array([3632.61328224]), inputs_are_outliers=array([False]), accepted_values=array([3721.206544]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-07 00:00:00'), input_values=array([2950.63050715]), inputs_are_outliers=array([False]), accepted_values=array([4110.95814992]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-08 00:00:00'), input_values=array([6484.76332758]), inputs_are_outliers=array([False]), accepted_values=array([4913.51735082]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-09 00:00:00'), input_values=array([4598.37224513]), inputs_are_outliers=array([False]), accepted_values=array([5004.05393376]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-10 00:00:00'), input_values=array([6918.39168458]), inputs_are_outliers=array([False]), accepted_values=array([4762.77623922]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-11 00:00:00'), input_values=array([2786.5689419]), inputs_are_outliers=array([False]), accepted_values=array([3868.99633487]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-12 00:00:00'), input_values=array([2601.35116567]), inputs_are_outliers=array([False]), accepted_values=array([3069.54118614]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-13 00:00:00'), input_values=array([2331.81027574]), inputs_are_outliers=array([False]), accepted_values=array([2352.50937129]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-14 00:00:00'), input_values=array([1477.71986007]), inputs_are_outliers=array([False]), accepted_values=array([2329.66621677]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-15 00:00:00'), input_values=array([2863.32539379]), inputs_are_outliers=array([False]), accepted_values=array([2625.63403368]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-16 00:00:00'), input_values=array([2683.01423937]), inputs_are_outliers=array([False]), accepted_values=array([2878.27956183]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-17 00:00:00'), input_values=array([4114.28855102]), inputs_are_outliers=array([False]), accepted_values=array([3117.69709926]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-18 00:00:00'), input_values=array([2824.15307258]), inputs_are_outliers=array([False]), accepted_values=array([3063.82528593]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-19 00:00:00'), input_values=array([2788.53114788]), inputs_are_outliers=array([False]), accepted_values=array([2583.44192777]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-20 00:00:00'), input_values=array([2711.92458394]), inputs_are_outliers=array([False]), accepted_values=array([1850.97986505]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-21 00:00:00'), input_values=array([177.28653417]), inputs_are_outliers=array([False]), accepted_values=array([1207.51065402]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-22 00:00:00'), input_values=array([529.42914644]), inputs_are_outliers=array([False]), accepted_values=array([715.60310457]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-23 00:00:00'), input_values=array([122.736]), inputs_are_outliers=array([False]), accepted_values=array([476.65072566]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-24 00:00:00'), input_values=array([672.09312544]), inputs_are_outliers=array([False]), accepted_values=array([569.00074998]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-25 00:00:00'), input_values=array([998.36249055]), inputs_are_outliers=array([False]), accepted_values=array([873.90516067]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-26 00:00:00'), input_values=array([463.19549486]), inputs_are_outliers=array([False]), accepted_values=array([1011.77002675]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-27 00:00:00'), input_values=array([2311.09269058]), inputs_are_outliers=array([False]), accepted_values=array([962.67051881]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-28 00:00:00'), input_values=array([384.8979567]), inputs_are_outliers=array([False]), accepted_values=array([849.1525776]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-29 00:00:00'), input_values=array([271.19221972]), inputs_are_outliers=array([False]), accepted_values=array([1148.7902285]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-30 00:00:00'), input_values=array([714.35317443]), inputs_are_outliers=array([False]), accepted_values=array([1600.40689165]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-01-31 00:00:00'), input_values=array([3176.96115166]), inputs_are_outliers=array([False]), accepted_values=array([1945.62735888]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-01 00:00:00'), input_values=array([3916.89446002]), inputs_are_outliers=array([False]), accepted_values=array([2006.44774255]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-02 00:00:00'), input_values=array([513.25294186]), inputs_are_outliers=array([False]), accepted_values=array([1705.31377095]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-03 00:00:00'), input_values=array([618.2468254]), inputs_are_outliers=array([False]), accepted_values=array([1206.04586788]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-04 00:00:00'), input_values=array([562.88459265]), inputs_are_outliers=array([False]), accepted_values=array([766.05568825]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-05 00:00:00'), input_values=array([1408.11595309]), inputs_are_outliers=array([False]), accepted_values=array([968.32641171]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-06 00:00:00'), input_values=array([634.69939496]), inputs_are_outliers=array([False]), accepted_values=array([1225.07587122]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-07 00:00:00'), input_values=array([1668.65443741]), inputs_are_outliers=array([False]), accepted_values=array([1443.23974012]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-08 00:00:00'), input_values=array([1948.90865077]), inputs_are_outliers=array([False]), accepted_values=array([1306.61813965]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-09 00:00:00'), input_values=array([1547.39285792]), inputs_are_outliers=array([False]), accepted_values=array([1095.83069165]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-10 00:00:00'), input_values=array([42.49400374]), inputs_are_outliers=array([False]), accepted_values=array([963.75721793]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-11 00:00:00'), input_values=array([69.8815284]), inputs_are_outliers=array([False]), accepted_values=array([949.69008025]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-12 00:00:00'), input_values=array([1948.90865077]), inputs_are_outliers=array([False]), accepted_values=array([978.84511213]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-13 00:00:00'), input_values=array([1668.65443741]), inputs_are_outliers=array([False]), accepted_values=array([1217.96485242]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-14 00:00:00'), input_values=array([634.69939496]), inputs_are_outliers=array([False]), accepted_values=array([1225.07587122]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-15 00:00:00'), input_values=array([1408.11595309]), inputs_are_outliers=array([False]), accepted_values=array([968.32641171]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-16 00:00:00'), input_values=array([562.88459265]), inputs_are_outliers=array([False]), accepted_values=array([766.05568825]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-17 00:00:00'), input_values=array([618.2468254]), inputs_are_outliers=array([False]), accepted_values=array([713.24671371]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-18 00:00:00'), input_values=array([513.25294186]), inputs_are_outliers=array([False]), accepted_values=array([988.29523249]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-19 00:00:00'), input_values=array([684.77062711]), inputs_are_outliers=array([False]), accepted_values=array([1574.48278715]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-20 00:00:00'), input_values=array([3176.96115166]), inputs_are_outliers=array([False]), accepted_values=array([1782.26723474]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-21 00:00:00'), input_values=array([3210.09416331]), inputs_are_outliers=array([False]), accepted_values=array([1734.98491319]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-22 00:00:00'), input_values=array([271.19221972]), inputs_are_outliers=array([False]), accepted_values=array([1702.44864282]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-23 00:00:00'), input_values=array([384.8979567]), inputs_are_outliers=array([False]), accepted_values=array([1229.67606987]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-24 00:00:00'), input_values=array([2311.09269058]), inputs_are_outliers=array([False]), accepted_values=array([962.67051881]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-25 00:00:00'), input_values=array([463.19549486]), inputs_are_outliers=array([False]), accepted_values=array([1011.77002675]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-26 00:00:00'), input_values=array([998.36249055]), inputs_are_outliers=array([False]), accepted_values=array([873.90516067]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-27 00:00:00'), input_values=array([672.09312544]), inputs_are_outliers=array([False]), accepted_values=array([569.00074998]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-02-28 00:00:00'), input_values=array([122.736]), inputs_are_outliers=array([False]), accepted_values=array([476.65072566]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-01 00:00:00'), input_values=array([529.42914644]), inputs_are_outliers=array([False]), accepted_values=array([375.8446981]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-02 00:00:00'), input_values=array([177.28653417]), inputs_are_outliers=array([False]), accepted_values=array([713.16508956]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-03 00:00:00'), input_values=array([483.54973046]), inputs_are_outliers=array([False]), accepted_values=array([1290.81295341]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-04 00:00:00'), input_values=array([2788.53114788]), inputs_are_outliers=array([False]), accepted_values=array([2089.09636332]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-05 00:00:00'), input_values=array([2824.15307258]), inputs_are_outliers=array([False]), accepted_values=array([2702.61344269]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-06 00:00:00'), input_values=array([4114.28855102]), inputs_are_outliers=array([False]), accepted_values=array([3086.48253293]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-07 00:00:00'), input_values=array([2542.30749559]), inputs_are_outliers=array([False]), accepted_values=array([2842.90882427]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-08 00:00:00'), input_values=array([2863.32539379]), inputs_are_outliers=array([False]), accepted_values=array([2594.41946735]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-09 00:00:00'), input_values=array([1477.71986007]), inputs_are_outliers=array([False]), accepted_values=array([2308.21277999]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-10 00:00:00'), input_values=array([2331.81027574]), inputs_are_outliers=array([False]), accepted_values=array([2352.50937129]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-11 00:00:00'), input_values=array([2601.35116567]), inputs_are_outliers=array([False]), accepted_values=array([2453.54442616]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-12 00:00:00'), input_values=array([2786.5689419]), inputs_are_outliers=array([False]), accepted_values=array([2371.21914655]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-13 00:00:00'), input_values=array([2878.25120932]), inputs_are_outliers=array([False]), accepted_values=array([2232.72364485]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-14 00:00:00'), input_values=array([653.26456469]), inputs_are_outliers=array([False]), accepted_values=array([2185.95157501]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-15 00:00:00'), input_values=array([2292.0603468]), inputs_are_outliers=array([False]), accepted_values=array([2208.40086073]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-16 00:00:00'), input_values=array([2950.63050715]), inputs_are_outliers=array([False]), accepted_values=array([2346.57558579]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-17 00:00:00'), input_values=array([2583.39153404]), inputs_are_outliers=array([False]), accepted_values=array([2818.19626873]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-18 00:00:00'), input_values=array([2778.72244254]), inputs_are_outliers=array([False]), accepted_values=array([3189.48279247]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-19 00:00:00'), input_values=array([3596.20314952]), inputs_are_outliers=array([False]), accepted_values=array([3543.50463815]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-20 00:00:00'), input_values=array([4395.6473537]), inputs_are_outliers=array([False]), accepted_values=array([3588.80042643]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-21 00:00:00'), input_values=array([4289.62377911]), inputs_are_outliers=array([False]), accepted_values=array([3531.85230467]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-22 00:00:00'), input_values=array([2038.1498593]), inputs_are_outliers=array([False]), accepted_values=array([3140.31602125]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-23 00:00:00'), input_values=array([3134.65736523]), inputs_are_outliers=array([False]), accepted_values=array([3000.34955485]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-24 00:00:00'), input_values=array([2038.1498593]), inputs_are_outliers=array([False]), accepted_values=array([3140.31602125]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-25 00:00:00'), input_values=array([4289.62377911]), inputs_are_outliers=array([False]), accepted_values=array([3531.85230467]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-26 00:00:00'), input_values=array([4395.6473537]), inputs_are_outliers=array([False]), accepted_values=array([3588.80042643]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-27 00:00:00'), input_values=array([3596.20314952]), inputs_are_outliers=array([False]), accepted_values=array([3702.86829235]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-28 00:00:00'), input_values=array([2778.72244254]), inputs_are_outliers=array([False]), accepted_values=array([3421.35554114]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-29 00:00:00'), input_values=array([3628.61058625]), inputs_are_outliers=array([False]), accepted_values=array([3720.20034981]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-30 00:00:00'), input_values=array([2950.63050715]), inputs_are_outliers=array([False]), accepted_values=array([4109.49581294]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-03-31 00:00:00'), input_values=array([6484.76332758]), inputs_are_outliers=array([False]), accepted_values=array([4912.07135436]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-01 00:00:00'), input_values=array([4594.60509786]), inputs_are_outliers=array([False]), accepted_values=array([5003.1069516]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-02 00:00:00'), input_values=array([6918.39168458]), inputs_are_outliers=array([False]), accepted_values=array([4761.94053039]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-03 00:00:00'), input_values=array([2786.5689419]), inputs_are_outliers=array([False]), accepted_values=array([3868.42196115]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-04 00:00:00'), input_values=array([2601.35116567]), inputs_are_outliers=array([False]), accepted_values=array([3069.54118614]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-05 00:00:00'), input_values=array([2331.81027574]), inputs_are_outliers=array([False]), accepted_values=array([2352.50937129]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-06 00:00:00'), input_values=array([1477.71986007]), inputs_are_outliers=array([False]), accepted_values=array([2329.33982761]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-07 00:00:00'), input_values=array([2863.32539379]), inputs_are_outliers=array([False]), accepted_values=array([2625.15914025]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-08 00:00:00'), input_values=array([2680.87354943]), inputs_are_outliers=array([False]), accepted_values=array([2877.74143707]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-09 00:00:00'), input_values=array([4114.28855102]), inputs_are_outliers=array([False]), accepted_values=array([3117.22220583]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-10 00:00:00'), input_values=array([2824.15307258]), inputs_are_outliers=array([False]), accepted_values=array([3063.21526191]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-11 00:00:00'), input_values=array([2788.53114788]), inputs_are_outliers=array([False]), accepted_values=array([2583.02924148]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-12 00:00:00'), input_values=array([2710.06430682]), inputs_are_outliers=array([False]), accepted_values=array([1850.51223022]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-13 00:00:00'), input_values=array([177.28653417]), inputs_are_outliers=array([False]), accepted_values=array([1207.09796773]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-14 00:00:00'), input_values=array([529.42914644]), inputs_are_outliers=array([False]), accepted_values=array([715.31946971]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-15 00:00:00'), input_values=array([122.736]), inputs_are_outliers=array([False]), accepted_values=array([476.65072566]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-16 00:00:00'), input_values=array([672.09312544]), inputs_are_outliers=array([False]), accepted_values=array([569.00074998]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-17 00:00:00'), input_values=array([998.36249055]), inputs_are_outliers=array([False]), accepted_values=array([873.90516067]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-18 00:00:00'), input_values=array([463.19549486]), inputs_are_outliers=array([False]), accepted_values=array([1011.77002675]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-19 00:00:00'), input_values=array([2311.09269058]), inputs_are_outliers=array([False]), accepted_values=array([962.67051881]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-20 00:00:00'), input_values=array([384.8979567]), inputs_are_outliers=array([False]), accepted_values=array([849.09968959]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-21 00:00:00'), input_values=array([271.19221972]), inputs_are_outliers=array([False]), accepted_values=array([1148.7132769]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-22 00:00:00'), input_values=array([714.00629763]), inputs_are_outliers=array([False]), accepted_values=array([1600.31969407]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-23 00:00:00'), input_values=array([3176.96115166]), inputs_are_outliers=array([False]), accepted_values=array([1945.55040728]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-24 00:00:00'), input_values=array([3916.89446002]), inputs_are_outliers=array([False]), accepted_values=array([2006.39485454]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-25 00:00:00'), input_values=array([513.25294186]), inputs_are_outliers=array([False]), accepted_values=array([1705.31377095]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-26 00:00:00'), input_values=array([618.2468254]), inputs_are_outliers=array([False]), accepted_values=array([1206.04586788]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-27 00:00:00'), input_values=array([562.88459265]), inputs_are_outliers=array([False]), accepted_values=array([766.05568825]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-28 00:00:00'), input_values=array([1408.11595309]), inputs_are_outliers=array([False]), accepted_values=array([968.32641171]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-29 00:00:00'), input_values=array([634.69939496]), inputs_are_outliers=array([False]), accepted_values=array([1225.07587122]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-04-30 00:00:00'), input_values=array([1668.65443741]), inputs_are_outliers=array([False]), accepted_values=array([1443.21564211]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan])),
#   FilterRow(date=Timestamp('2022-05-01 00:00:00'), input_values=array([1948.90865077]), inputs_are_outliers=array([False]), accepted_values=array([1306.58307726]), predicted_values=array([nan]), predicted_upper_limits=array([nan]), predicted_lower_limits=array([nan]))],
#  'results_window': Window(source='results', size=0, position='back'),
#  'inputs_window': Window(source='inputs', size=5, position='centered')}

# %%
from data_filters.protocols import FilterRow
import numpy as np

a = FilterRow(
    date = pd.to_datetime("22 may 2022"),
    input_values=np.array([1]),
    inputs_are_outliers=np.array([1]),
    accepted_values=np.array([2]),
    predicted_values=np.array([2]),
    predicted_lower_limits=np.array([0]),
    predicted_upper_limits=np.array([3])
)

class FilterRowEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, FilterRow):
            return {f'__{obj.__class__.__name__}__': obj.__dict__}
        if isinstance(obj, pd.Timestamp):
            return json.dumps(obj, cls=TimestampEncoder)
        if isinstance(obj, np.ndarray):
            return json.dumps(obj, cls=NumpyEncoder)
        else:
            return json.JSONEncoder.default(self, obj)
            
def decode_filter_row(obj):
    if '__FilterRow__' in obj:
        a = FilterRow(
            obj['__FilterRow__']['date'],
            obj['__FilterRow__']['input_values'],
            obj['__FilterRow__']['inputs_are_outliers'],
            obj['__FilterRow__']['accepted_values'],
            obj['__FilterRow__']['predicted_values'],
            obj['__FilterRow__']['predicted_lower_limits'],
            obj['__FilterRow__']['predicted_upper_limits'])
        a.__dict__.update(obj['__FilterRow__'])
        return a
    elif '__Timestamp__' in obj:
        return decode_timestamp(obj)
    elif '__Array__' in obj:
         return decode_numpy(obj)
    else:
        return obj

a = json.dumps(a, cls=FilterRowEncoder)
b = json.loads(a, object_hook=decode_filter_row)
b
# Out:
# FilterRow(date='{"__Timestamp__": "2022-05-22 00:00:00"}', input_values='[1]', inputs_are_outliers='[1]', accepted_values='[2]', predicted_values='[2]', predicted_upper_limits='[3]', predicted_lower_limits='[0]')

# %%
# Out:
# Timestamp('2022-05-22 00:00:00')

# %%
# Out:
# numpy.int64
